# %% [markdown]
# #### BBC covid -vaccine news (Centerist)

# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd

#to make the code work through pages
pagesToGet= 1

upperframe=[]  
for page in range(1,pagesToGet+10):
    print('processing page :', page)
    url = 'https://www.bbc.co.uk/search?q=vaccine&page='+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('div',attrs={'class':'ssrcss-11rb3jo-Promo ett16tt0'})
    print(len(links))
    
    for j in links:
        Headline = j.find("p",attrs={'class':'ssrcss-6arcww-PromoHeadline e1f5wbog4'}).text.strip()
        Description = j.find("p",attrs={'class':'ssrcss-1q0x1qg-Paragraph eq5iqo00'}).text.strip()
    
        frame.append((Headline,Description))
        
    upperframe.extend(frame)

data_bbc=pd.DataFrame(upperframe, columns=['Headline', 'Description'])
data_bbc["Article"] = data_bbc["Headline"].map(str) +" "+ data_bbc["Description"].map(str)

data_bbc.head()
# Out:
# processing page : 1
# https://www.bbc.co.uk/search?q=vaccine&page=1
# 10
# processing page : 2
# https://www.bbc.co.uk/search?q=vaccine&page=2
# 10
# processing page : 3
# https://www.bbc.co.uk/search?q=vaccine&page=3
# 10
# processing page : 4
# https://www.bbc.co.uk/search?q=vaccine&page=4
# 10
# processing page : 5
# https://www.bbc.co.uk/search?q=vaccine&page=5
# 10
# processing page : 6
# https://www.bbc.co.uk/search?q=vaccine&page=6
# 10
# processing page : 7
# https://www.bbc.co.uk/search?q=vaccine&page=7
# 10
# processing page : 8
# https://www.bbc.co.uk/search?q=vaccine&page=8
# 10
# processing page : 9
# https://www.bbc.co.uk/search?q=vaccine&page=9
# 10
# processing page : 10
# https://www.bbc.co.uk/search?q=vaccine&page=10
# 10
#                                       Headline  \
# 0             Hayley Goes... Vaccine Frontline
# 1          Global Questions: Vaccine Apartheid
# 2  Horizon: 2021: Horizon Special: The Vaccine
# 3           Panorama: The Virus vs the Vaccine
# ...

# %% [markdown]
# #### Jacobin covid vaccine (Left-Wing)

# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd

pagesToGet= 1

upperframe=[]  
for page in range(1,pagesToGet+5):
    print('processing page :', page)
    url = 'https://jacobinmag.com/search?query=covid%20vaccination&page='+str(page)
    print(url)
    
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.
    
    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
        continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('div',attrs={'class':'ar-mn__main'})
    print(len(links))

    
    for j in links:
        Headline = j.find("h1",attrs={'class':'ar-mn__title'}).text.strip()
        Description = j.find("p",attrs={'class':'ar-mn__summary'}).text.strip()
    
        frame.append((Headline,Description))
        
    upperframe.extend(frame)

data=pd.DataFrame(upperframe, columns=['Headline', 'Description'])
data["Article"] = data["Headline"].map(str) +" "+data["Description"].map(str)
data.head()
# Out:
# processing page : 1
# https://jacobinmag.com/search?query=covid%20vaccination&page=1
# 20
# processing page : 2
# https://jacobinmag.com/search?query=covid%20vaccination&page=2
# 20
# processing page : 3
# https://jacobinmag.com/search?query=covid%20vaccination&page=3
# 20
# processing page : 4
# https://jacobinmag.com/search?query=covid%20vaccination&page=4
# 20
# processing page : 5
# https://jacobinmag.com/search?query=covid%20vaccination&page=5
# 10
#                                             Headline  \
# 0  Our Political Leaders Could Have Prevented Mas...
# 1  The Australian Left Must Fight for a Strategy ...
# 2  Tough on Anti-Vaxx Nonsense, Tough on the Caus...
# 3  Blame Modi and the BJP for India’s COVID-19 Ca...
# 4  Thank Socialism for the Vaccine. Blame Capital...
#
#                                          Description  \
# 0  The US has never seriously considered far-reac...
# 1  The highly infectious Delta variant is spreadi...
# ...

# %% [markdown]
# #### India Today

# %%
links=[]
for x in range(0,10):
    webpage = 'https://www.indiatoday.in/coronavirus-outbreak/vaccine-updates'

    url = webpage+'?page='+str(x)
    #an exception might be thrown, so the code should be in a try-except block
    try:
        #use the browser to get the url. This is suspicious command that might blow up.
        page=requests.get(url)                             # this might throw an exception if something goes wrong.

    except Exception as e:                                   # this describes what to do if an exception is thrown
        error_type, error_obj, error_info = sys.exc_info()      # get the exception information
        print ('ERROR FOR LINK:',url)                          #print the link that cause the problem
        print (error_type, 'Line:', error_info.tb_lineno)     #print error info and line that threw the exception
       # continue                                              #ignore this page. Abandon this and go back.
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    page_links=soup.find_all('div',attrs={'class':'detail'})
    links.extend(page_links)
    
    article_content = []
    article_descr=[]
    article_title=[]
for j in links:
        article_arr = j.find("h2",attrs={'class':''}).text.strip()
        article_desc = j.find("p",attrs={'class':''}).text.strip()
        article_content.append(article_arr+' '+article_desc)
        article_title.append(article_arr)
        article_descr.append(article_desc)

article_df = pd.DataFrame({"Headline":article_title,"Description":article_descr,"Article": article_content})
article_df.head()
# Out:
#                                             Headline  \
# 0  Could quality concerns over Novavax’s Covid va...
# 1  Vaccine maker Bharat Biotech's US partner seek...
# 2  100 crore jabs answer to questions raised on I...
# 3  'From anxiety to assurance': PM Modi lauds Ind...
# 4  India hits record 1 billion Covid-19 vaccinati...
#
#                                          Description  \
# 0  Novavax is facing significant hurdles in provi...
# 1  Hyderabad-based vaccine maker Bharat Biotech's...
# 2  In a veiled attack on the Opposition, Prime Mi...
# 3  A day after India touched the 100 crore Covid-...
# 4  India on Thursday hit a historic milestone in ...
#
#                                              Article
# 0  Could quality concerns over Novavax’s Covid va...
# 1  Vaccine maker Bharat Biotech's US partner seek...
# 2  100 crore jabs answer to questions raised on I...
# 3  'From anxiety to assurance': PM Modi lauds Ind...
# 4  India hits record 1 billion Covid-19 vaccinati...

# %% [markdown]
# ###### Data cleaning- BBC, Jacobin

# %%
#Removing punctuation
data['Headline'] = data['Headline'].replace('[^\w\s]','',regex=True)
data['Description']= data['Description'].replace('[^\w\s]','',regex=True)
data['Article']= data['Article'].replace('[^\w\s]','',regex=True)
data_bbc['Headline'] = data_bbc['Headline'].replace('[^\w\s]','',regex=True)
data_bbc['Description']= data_bbc['Description'].replace('[^\w\s]','',regex=True)
data_bbc['Article']= data_bbc['Article'].replace('[^\w\s]','',regex=True)

# %% [markdown]
# ###### Data cleaing - India Today

# %%
import re
import nltk
from nltk.corpus import stopwords
stopwords=nltk.corpus.stopwords.words('english')
additional =["thank you","please","hello","hi","hin't","st","nd","rd","th","thank","a","the"]
stopwords = stopwords + additional
remov=[]
for ele in stopwords:
    matches = re.findall("n't",ele)
    matches2 = re.findall("'nt",ele)
    if len(matches)>0 or len(matches2)>0:
        remov.append(ele)
stopwords = [word for word in stopwords if word not in remov]

article_df = pd.DataFrame({"Headline":article_title,"Description":article_descr,"Article": article_content})

#Removing punctuation
article_df["Article"] = article_df["Article"].replace('[^\w\s]','',regex=True)
#Remove Stopwords
article_df["Article"] = article_df["Article"].apply(lambda x: " ". join(x.lower() for x in str(x).split() if x not in stopwords))

data['Description'] = data['Description'].apply(lambda x: " ". join(x.lower() for x in str(x).split() if x not in stopwords))
data['Headline']=data['Headline'].apply(lambda x: " ". join(x.lower() for x in str(x).split() if x not in stopwords))
data_bbc['Headline']=data_bbc['Headline'].apply(lambda x: " ". join(x.lower() for x in str(x).split() if x not in stopwords))
data_bbc['Description'] = data_bbc['Description'].apply(lambda x: " ". join(x.lower() for x in str(x).split() if x not in stopwords))

# %%
print(data_bbc['Description'][1])
# Out:
# people argue global vaccine apartheid unfolding. zeinab badawi guests discuss.

# %%
#article_df.head()

# %%
data["Publisher"] = 'Jacobin'
data_bbc["Publisher"] = 'BBC'
article_df["Publisher"]= 'India_Today'
data_bbc
frames = [data, data_bbc,article_df]
result = pd.concat(frames,ignore_index=True)
len(result)
# Out:
# 310

# %%
#result['Article'][51]

# adding data to mongodb after cleaning

# %%
#type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
import requests
from pymongo import MongoClient
import certifi
cluster = MongoClient("mongodb+srv://user:11223344@cluster0.nmzhw.mongodb.net/myFirstDatabase?retryWrites=true&w=majority",tlsCAFile= certifi.where())

# %%
db = cluster["News"]
rec = db["News_clean"]

my_list = result.to_dict('records')
rec.insert_many(my_list)

# %%
#getting data from mongodb to do the sentiment analysis
#and storing in dataframe result

# %%
query={}
x = rec.find(query)
result =  pd.DataFrame(list(x))
del result['_id'] #deleting the id column
result
# Out:
#                                               Headline  \
# 0    our political leaders could have prevented mas...
# 1    the australian left must fight strategy that w...
# 2    tough antivaxx nonsense tough causes antivaxx ...
# 3            blame modi bjp indias covid19 catastrophe
# 4    thank socialism vaccine blame capitalism its d...
# ..                                                 ...
# 305  Covid-19: Moscow starts early trials of Sputni...
# 306  No antibodies against Delta variant in 16% sam...
# 307  Covid vaccination: Is faulty injection techniq...
# 308  Mumbaikars struggle to get their second dose o...
# 309  Flexible, agile Covid vaccination strategy vit...
#
#                                            Description  \
# 0    the us never seriously considered farreaching ...
# 1    the highly infectious delta variant spreading ...
# 2    perhaps months away first covid19 vaccines eff...
# 3    from lack investment public health care mishan...
# ...

# %% [markdown]
# ### Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

sentiment_results = []
sent_res_neg = []
sent_res_pos = []
sent_res_neu = []
for item in result['Article']:
    sentiment_statement = analyser.polarity_scores(item)
    sentiment_results.append(sentiment_statement['compound'])
    sent_res_neg.append(sentiment_statement['neg'])
    sent_res_pos.append(sentiment_statement['neu'])
    sent_res_neu.append(sentiment_statement['pos'])

# %%
sentiment_results
# Out:
# [0.6147,
#  -0.6369,
#  -0.9062,
#  -0.926,
#  -0.8338,
#  0.9807,
#  -0.0516,
#  -0.5719,
#  0.9719,
#  0.9216,
#  0.8569,
#  -0.9717,
#  -0.8126,
#  -0.6461,
#  -0.34,
#  -0.7003,
#  -0.8338,
#  0.1253,
#  -0.4717,
#  -0.7783,
#  -0.9446,
#  0.296,
#  -0.5994,
#  0.3612,
#  0.5423,
#  -0.9628,
#  -0.7391,
#  -0.3612,
#  -0.9231,
#  0.6249,
#  0.7927,
#  -0.6981,
#  -0.25,
#  0.1027,
#  0.0772,
#  -0.4215,
#  0.7579,
#  -0.8555,
#  0.1027,
#  0.9091,
#  -0.9432,
#  0.3818,
#  -0.2023,
#  -0.5423,
#  0.7351,
#  -0.5423,
#  -0.8285,
#  0.8126,
#  -0.4588,
#  -0.6836,
#  0.0433,
#  -0.0572,
#  -0.9178,
#  0.8126,
#  -0.0516,
#  -0.9062,
#  0.8847,
#  0.6705,
#  -0.3919,
#  0.5187,
#  0.7549,
#  -0.9393,
#  -0.2023,
#  -0.5267,
#  0.5994,
#  0.7494,
#  -0.4215,
#  0.9158,
#  0.7227,
#  -0.9377,
#  -0.3612,
#  -0.4588,
#  -0.6369,
#  -0.4767,
#  0.4939,
#  -0.9042,
#  -0.7003,
#  0.4199,
#  -0.7854,
#  0.6705,
#  0.6369,
#  0.3612,
#  0.9349,
#  -0.4404,
#  -0.5106,
#  0.9423,
# ...

# %%
result["Sentiment Compound Score"] = sentiment_results
result["Negative Sentiment Score"] = sent_res_neg
result["Neutral Sentiment Score"] = sent_res_neu
result["Positive Sentiment Score"] = sent_res_pos

# %%
result
# Out:
#                                               Headline  \
# 0    our political leaders could have prevented mas...
# 1    the australian left must fight strategy that w...
# 2    tough antivaxx nonsense tough causes antivaxx ...
# 3            blame modi bjp indias covid19 catastrophe
# 4    thank socialism vaccine blame capitalism its d...
# ..                                                 ...
# 305  Covid-19: Moscow starts early trials of Sputni...
# 306  No antibodies against Delta variant in 16% sam...
# 307  Covid vaccination: Is faulty injection techniq...
# 308  Mumbaikars struggle to get their second dose o...
# 309  Flexible, agile Covid vaccination strategy vit...
#
#                                            Description  \
# 0    the us never seriously considered farreaching ...
# 1    the highly infectious delta variant spreading ...
# 2    perhaps months away first covid19 vaccines eff...
# 3    from lack investment public health care mishan...
# ...

# %%
# Create new column to label the sentiment as positive or negative
pos=0
neg=0
neu=0
sntmnt =[]
for i in result['Sentiment Compound Score']:
    if i > 0.2:
        pos+=1
        sntmnt.append('Positive')
    elif i < -0.2:
        sntmnt.append('Negative')
        neg+=1
    else:
        sntmnt.append('Neutral')
        neu+=1

# %%
# create a dataframe series 
result["Sentiment"] = sntmnt

# %%
# Testing the results : How many positive, negative and neutral articles are there for each Publisher
x=0
pos1=0
neg1=0
neu1=0
for x in range(0,309) :
    if result['Publisher'][x] == 'Jacobin':
        if result['Sentiment Compound Score'][x] > 0.2:            
            pos1+=1      
        elif result['Sentiment Compound Score'][x] < -0.2:
            neg1+=1
        else:     
            neu1+=1
print(pos1,neu1,neg1)
# Out:
# 34 8 48

# %%
result
# Out:
#                                               Headline  \
# 0    our political leaders could have prevented mas...
# 1    the australian left must fight strategy that w...
# 2    tough antivaxx nonsense tough causes antivaxx ...
# 3            blame modi bjp indias covid19 catastrophe
# 4    thank socialism vaccine blame capitalism its d...
# ..                                                 ...
# 305  Covid-19: Moscow starts early trials of Sputni...
# 306  No antibodies against Delta variant in 16% sam...
# 307  Covid vaccination: Is faulty injection techniq...
# 308  Mumbaikars struggle to get their second dose o...
# 309  Flexible, agile Covid vaccination strategy vit...
#
#                                            Description  \
# 0    the us never seriously considered farreaching ...
# 1    the highly infectious delta variant spreading ...
# 2    perhaps months away first covid19 vaccines eff...
# 3    from lack investment public health care mishan...
# ...

# %%
#result.to_csv("Sentiment_Results.csv", index=False)

# %%
# adding data to mongodb

# %%
recs = db["News_sa"]
#len(result)

# %%
#Code to insert the data to db if we have large data as this one is going to send the data in chunks
#chunk_size=100
#my_list = result.to_dict('records')
#l =  len(my_list)
#ran = range(l)
#steps=ran[chunk_size::chunk_size]


# Insert chunks of the dataframe
#i = 0
#for j in steps:
    #print (j)
 #   rec.insert_many(my_list[i:j]) # fill de collection
  #  i = j

# %%
#Code to Insert the data to db if we have small data and
#all the data can be sent to the database without hurting the server.

my_list = result.to_dict('records')
recs.insert_many(my_list)

# %%
# !pip install pytorch-pretrained-bert
# Out:
# Traceback (most recent call last):
#   File "d:\minicondainstall\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "d:\minicondainstall\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "D:\minicondainstall\Scripts\pip.exe\__main__.py", line 4, in <module>
# ModuleNotFoundError: No module named 'pip'
